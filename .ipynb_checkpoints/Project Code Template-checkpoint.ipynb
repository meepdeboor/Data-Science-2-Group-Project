# %% [raw]
# ---
# title: "Project Code"
# subtitle: Team name
# author: Author 1, Author 2, Author 3, and Author 4
# date: 02/27/2023
# number-sections: true
# abstract: _This file contains the code for the project on <>, as part of the STAT303-2 course in Winter 2023_.
# format:
#   html:
#     toc: true
#     toc-title: Contents
#     self-contained: true
#     font-size: 100%
#     toc-depth: 4
#     mainfont: serif
# jupyter: python3
# ---

# %% [markdown]
# ## Length of the code {-}
# No restriction
#
# **Delete this section from the report, when using this template.**

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as sm
import itertools
water = pd.read_csv('drinking_water_potability.csv')
water.head()
# Out:
#          ph    Hardness       Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890456  20791.31898     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.05786     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.54173     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.41744     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.98634     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436525       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %% [markdown]
# ## Data quality check / cleaning / preparation
#
# Put code with comments. The comments should explain the code such that it can be easily understood. You may put text *(in a markdown cell)* before a large chunk of code to explain the overall purpose of the code, if it is not intuitive. **Put the name of the person / persons who contributed to each code chunk / set of code chunks.** An example is given below.

# %% [markdown]
# ### Data quality check
# *By Henry Shavel*

# %% [markdown]
# The code below visualizes the distribution of all the variables in the dataset, and their association with the response.

# %%
#...Distribution of continuous variables...#
fig, axes = plt.subplots(2,4,figsize=(16,10))
plt.subplots_adjust(wspace=0.2)
axes[0,0].hist(x ="ph", data = water, bins = 20)
axes[0,0].set_xlabel("ph",fontsize = 12)
axes[0,1].hist(x = "Hardness", data = water, bins = 20)
axes[0,1].set_xlabel("Hardness",fontsize = 12)
axes[0,2].hist(x = "Chloramines", data = water, bins = 20)
axes[0,2].set_xlabel("Chloramines",fontsize = 12)
axes[0,3].hist(x = "Sulfate", data = water, bins = 20)
axes[0,3].set_xlabel("Sulfate",fontsize = 12)
axes[1,0].hist(x = "Conductivity", data = water, bins = 20)
axes[1,0].set_xlabel("Conductivity",fontsize = 12)
axes[1,1].hist(x = "Organic_carbon", data = water, bins = 20)
axes[1,1].set_xlabel("Organic_carbon",fontsize = 12)
axes[1,2].hist(x = "Trihalomethanes", data = water, bins = 20)
axes[1,2].set_xlabel("Trihalomethanes",fontsize = 12)
axes[1,3].hist(x = "Turbidity", data = water, bins = 20)
axes[1,3].set_xlabel("Turbidity",fontsize = 12)
# Out:
# Text(0.5, 0, 'Turbidity')

# %%
#...Distribution of categorical variables...#
#sns.barplot(x ="Potability", data = water)
ax = water['Potability'].value_counts().plot.bar(ylabel = 'Count', xlabel = 'Potability')
plt.xticks([0,1], [0,1], rotation='horizontal')
# Out:
# ([<matplotlib.axis.XTick at 0x7fa2ba2b6a00>,
#   <matplotlib.axis.XTick at 0x7fa27ad19280>],
#  [Text(0, 0, '0'), Text(1, 0, '1')])

# %%
water.Potability.value_counts(1)
# Out:
# 0    0.60989
# 1    0.39011
# Name: Potability, dtype: float64

# %%
#...Association of the response with the predictors...#
fig, axes = plt.subplots(2,4,figsize=(16,10))
plt.subplots_adjust(wspace=0.2)
sns.boxplot(ax = axes[0,0], x = "Potability", y="ph", data = water)
axes[0,0].set_title("Ph")
sns.boxplot(ax = axes[0,1], x = "Potability", y="Hardness", data = water)
axes[0,1].set_title("Hardness")
sns.boxplot(ax = axes[0,2], x = "Potability", y="Solids", data = water)
axes[0,2].set_title("Solids")
sns.boxplot(ax = axes[0,3], x = "Potability", y="Chloramines", data = water)
axes[0,3].set_title("Chloramines")
sns.boxplot(ax = axes[1,0], x = "Potability", y="Sulfate", data = water)
axes[1,0].set_title("Sulfate")
sns.boxplot(ax = axes[1,1], x = "Potability", y="Conductivity", data = water)
axes[1,1].set_title("Conductivity")
sns.boxplot(ax = axes[1,2], x = "Potability", y="Organic_carbon", data = water)
axes[1,2].set_title("Organic_carbon")
sns.boxplot(ax = axes[1,3], x = "Potability", y="Turbidity", data = water)
axes[1,3].set_title("Turbidity")
# Out:
# Text(0.5, 1.0, 'Turbidity')

# %% [markdown]
# ### Data cleaning
# *By Henry Shavel*
#
# From the data quality check we realized that:
#
# 1. There were only three columns that contained missing values, ph, chloramines, and trihalmoethanes.
#
# 2. However there were many missing values in each of these columns, 491, 781, and 162 respectively.
#
# 3. Since there were over 3200 rows initially and still over 2000 rows of data after dropping all rows with missing values, we determined that all missing values can be dropped and the dataset will still be big enough to prevent overfitting of the model.
#
# 4. After removing missing values, none of the columns needed more data cleaning since they were all numerical and no additional predictors were created from existing predictors.
#
#
# The code below implements the above cleaning.

# %%
#dropping all rows with missing values from the data frame.#
water = water.dropna()

# %% [markdown]
# ### Data preparation
# *By Sankaranarayanan Balasubramanian and Chun-Li*
#
# The following data preparation steps helped us to prepare our data for implementing various modeling / validation techniques:
#
# 1. Since we need to predict house price, we derived some new predictors *(from existing predictors)* that intuitively seem to be helpuful to predict house price.
#
# 2. We have shuffled the dataset to prepare it for K-fold cross validation.
#
# 3. We have created a standardized version of the dataset, as we will use it to develop Lasso / Ridge regression models.

# %%
######---------------Creating new predictors----------------#########

#Creating number of bedrooms per unit floor area

#Creating ratio of bathrooms to bedrooms

#Creating ratio of carpet area to floor area

# %%
######-----------Shuffling the dataset for K-fold------------#########

# %%
######-----Standardizing the dataset for Lasso / Ridge-------#########

# %%
#Shuffling the dataset for random selection of train and test data
np.random.seed(2)
# 80% to be training
train = water.sample(round(water.shape[0]*.8))
# drop the train data from the test df
test = water.drop(train.index)

# %% [markdown]
# ## Exploratory data analysis

# %% [markdown]
# Put code with comments. The comments should explain the code such that it can be easily understood. You may put text *(in a markdown cell)* before a large chunk of code to explain the overall purpose of the code, if it is not intuitive. **Put the name of the person / persons who contributed to each code chunk / set of code chunks.**
#
# *By Tyler McLaughlin*

# %%
fig, axes = plt.subplots(2,4,figsize=(16,10))
plt.subplots_adjust(wspace=0.2)
sns.boxplot(ax = axes[0,0], x = "Potability", y="ph", data = water)
axes[0,0].set_title("Ph")
sns.boxplot(ax = axes[0,1], x = "Potability", y="Hardness", data = water)
axes[0,1].set_title("Hardness")
sns.boxplot(ax = axes[0,2], x = "Potability", y="Solids", data = water)
axes[0,2].set_title("Solids")
sns.boxplot(ax = axes[0,3], x = "Potability", y="Chloramines", data = water)
axes[0,3].set_title("Chloramines")
sns.boxplot(ax = axes[1,0], x = "Potability", y="Sulfate", data = water)
axes[1,0].set_title("Sulfate")
sns.boxplot(ax = axes[1,1], x = "Potability", y="Conductivity", data = water)
axes[1,1].set_title("Conductivity")
sns.boxplot(ax = axes[1,2], x = "Potability", y="Organic_carbon", data = water)
axes[1,2].set_title("Organic_carbon")
sns.boxplot(ax = axes[1,3], x = "Potability", y="Turbidity", data = water)
axes[1,3].set_title("Turbidity")
# Out:
# Text(0.5, 1.0, 'Turbidity')

# %%
#Examining relationships between the explanatory variables (Scatterplot matrix)
sns.pairplot(water)

# %%
#Examining relationships between the explanatory variables (Correlation heatmap)
sns.set(rc={'figure.figsize':(12,10)})
sns.heatmap(water.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Developing the model

# %% [markdown]
# Put code with comments. The comments should explain the code such that it can be easily understood. You may put text *(in a markdown cell)* before a large chunk of code to explain the overall purpose of the code, if it is not intuitive. **Put the name of the person / persons who contributed to each code chunk / set of code chunks.**

# %% [markdown]
# ### Functions for Confusion Matrix, Classification Accuracy, Plotting Subset Selection
# *By Malva de Boor*

# %%
def confusion_matrix_test(data,actual_values,model,cutoff=0.5):
    #Predicting the values using the Logit model
    pred_values = model.predict(data)
    #Specifying the bins for the predicted probabilities
    bins=np.array([0,cutoff,1])
    #Creating the confusion matrix
    cm = np.histogram2d(actual_values, pred_values, bins=bins)[0]
    cm_df = pd.DataFrame(cm)
    cm_df.columns = ['Predicted 0','Predicted 1']
    cm_df = cm_df.rename(index={0: 'Actual 0',1:'Actual 1'})
    accuracy = (cm[0,0]+cm[1,1])/cm.sum()
    #Displaying the confusion matrix
    sns.heatmap(cm_df, annot=True, cmap='Blues', fmt='g')
    plt.ylabel("Actual Values")
    plt.xlabel("Predicted Values")
    print("Classification accuracy = {:.1%}".format(accuracy))
    return cm

#This function is the same as the one above except it returns the accuracy instead
#of the confusion matrix for easier use in variable selection later
def accuracytest(data,actual_values,model,cutoff=0.5):
    pred_values = model.predict(data)
    bins=np.array([0,cutoff,1])
    cm = np.histogram2d(actual_values, pred_values, bins=bins)[0]
    accuracy = (cm[0,0]+cm[1,1])/cm.sum()
    return accuracy

def best_sub_plots():
    plt.figure(figsize=(20,10))
    plt.rcParams.update({'font.size': 18, 'lines.markersize': 10})
    
    #Plotting selection based on Accuracy
    plt.subplot(2, 2, 1)
    accuracy = models_best.apply(lambda row: accuracytest(test,test.Potability,row[1],cutoff=0.5), axis=1)
    plt.plot(models_best["Accuracy"])
    plt.plot(1+accuracy.argmax(), accuracy.max(), "or") #plotting red dot on maximum
    plt.xlabel('# Predictors')
    plt.ylabel('Accuracy')
    
    #Plotting selection based on AIC
    plt.subplot(2, 2, 2)
    aic = models_best.apply(lambda row: row[1].aic, axis=1)
    plt.plot(aic)
    plt.plot(1+aic.argmin(), aic.min(), "or") #plotting red dot on minimum
    plt.xlabel('# Predictors')
    plt.ylabel('AIC')
    
    #Plotting selection based on BIC
    plt.subplot(2, 2, 3)
    bic = models_best.apply(lambda row: row[1].bic, axis=1)
    plt.plot(bic)
    plt.plot(1+bic.argmin(), bic.min(), "or") #plotting red dot on minimum
    plt.xlabel('# Predictors')
    plt.ylabel('BIC')

def processSubset(predictor_subset):
    #Fit model on feature_set and calculate classification accuracy
    #Model including all predictors in predictor_subset
    model = sm.logit('Potability~' + '+'.join(predictor_subset),data = train).fit() 
    accuracy = accuracytest(test,test.Potability,model,cutoff=0.5)
    return {"model":model, "Accuracy":accuracy}

# %% [markdown]
# ### Baseline Model
# *By Malva de Boor*

# %%
#Making a logistic model with all the predictors
logit_model = sm.logit(formula = 'Potability~ph+Hardness+Solids+Chloramines+Sulfate+\
                Organic_carbon+Conductivity+Turbidity+Trihalomethanes', data = water).fit() 
logit_model.summary()
#Displaying the confusion matrix and the FPR of the model
cm = confusion_matrix_test(water,water.Potability,logit_model,.5)
fpr = cm[0,1]/(cm[0,1]+cm[1,0])
print('FPR = {:.2%}'.format(fpr))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.672501
#          Iterations 4
# Classification accuracy = 59.8%
# FPR = 0.25%

# %% [markdown]
# ### Ridge Regression
# *By Albert Song*

# %%
from sklearn.preprocessing import StandardScaler 
#Defines dataframes for ridge regression

y = train.filter(items=['Potability'])
X = train.drop('Potability', axis=1)

testY = test.filter(items=['Potability'])
testX = test.drop('Potability', axis=1)

scaler = StandardScaler()

#The scaler object will contain the mean and variance of each column (predictor) of X. 
#These values will be useful to scale test data based on the same mean and variance as obtained on train data
scaler.fit(X)

#Using the scaler object (or the values of mean and variance stored in it) to standardize X (or train data)
Xstd = scaler.transform(X)
XTeststd = scaler.transform(testX)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.linear_model import RidgeClassifier
from sklearn.model_selection import GridSearchCV

#Creates ridge classifier object
model = RidgeClassifier()
#Defines cv test, with 10 splits and 3 repeated tries
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
#creates grid of alphas to test ridge on
grid = dict()
grid['alpha'] = np.arange(0, 1, 0.01)
#defines the search for the best model based on mae
search = GridSearchCV(model, grid, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
# perform the search
results = search.fit(Xstd, y)
print('Best MAE is %.3f' % results.best_score_)
print('Best alpha param is %s' % results.best_params_)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best MAE is -0.348
# Best alpha param is {'alpha': 0.02}
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
ridgeModel = RidgeClassifier(alpha = 0)
predictedY = ridgeModel.fit(Xstd, y).predict(XTeststd)
#Determining false/true positives/negatives for precision and accuracu
tp = 0
tn = 0
fp = 0
fn = 0
for ii in range(0, len(predictedY)):
    if predictedY[ii] == 0:
        if testY.iloc[ii][0] == 0:
            tn += 1
        else:
            fn +=1
    else:
        if testY.iloc[ii][0] == 1:
            tp += 1
        else:
            fp += 1

#calculating precision and accuracy           
print(str((tp+tn) / len(predictedY)) + ' Accuracy')
print(str(fp / (tp + fp)) + ' Precision')
# Out:
# 0.7114427860696517 Accuracy
# 0.23529411764705882 Precision
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:1059: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ### Forward Selection
# *By Malva de Boor*

# %%
#Eliminating dataframe reassignment errors
pd.set_option('mode.chained_assignment', None)
from warnings import simplefilter
simplefilter(action="ignore", category=pd.errors.PerformanceWarning)

# %%
#Creating a dataframe with all the predictors
X = train.loc[:, train.columns!='Potability']
train2 = train.copy()
test2 = test.copy()
#backup X
X_backup = train.loc[:, train.columns!='Potability']
#Including 2-factor interactions of predictors in train and 'X'. 
for combo in itertools.combinations(X_backup.columns, 2):    
    train['_'.join(combo)] = train[combo[0]]*train[combo[1]]
    test['_'.join(combo)] = test[combo[0]]*test[combo[1]]
    X.loc[:,'_'.join(combo)] = train.loc[:,'_'.join(combo)]

# %%
#Function to find the best predictor out of p-k predictors and add it to the model containing the k predictors
def forward(predictors):

    # Pull out predictors that still haven't been added to the model
    remaining_predictors = [p for p in X.columns if p not in predictors]
    results = []
    
    #making a model for every possible new predictor
    for p in remaining_predictors:
        results.append(processSubset(predictors+[p]))

    models = pd.DataFrame(results)
    
    #Choose the model with the highest Accuracy
    best_model = models.loc[models['Accuracy'].argmax()]

    #Return the best model
    return best_model

def forward_selection():
    models_best = pd.DataFrame(columns=["Accuracy", "model"])

    predictors = []
    
    for i in range(1,len(X.columns)+1):    
        models_best.loc[i] = forward(predictors) #calling forward selection
        #setting predictors in model equal to the ones used in the current iteration in
        #preparation for the next iteration
        predictors = list(models_best.loc[i]["model"].params.index[1:])  
    return models_best

models_best = forward_selection()
best_sub_plots() #plot the results
# Out:
# Optimization terminated successfully.
#          Current function value: 0.676568
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676692
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675115
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676696
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676274
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676614
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676644
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676702
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676556
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676697
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.672820
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676056
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676380
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676700
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676700
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676655
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676279
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675667
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676638
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676516
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676678
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676594
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676702
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676619
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676219
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676434
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675529
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675815
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675223
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675043
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676578
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676638
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676626
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676702
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676650
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676300
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676433
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676537
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676702
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676623
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676700
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676701
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676671
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676699
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676651
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675324
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675525
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675109
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675527
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675299
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674900
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675460
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675529
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675411
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675502
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.672517
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674741
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675364
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675502
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675521
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675447
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675057
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675466
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675485
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675444
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675313
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675421
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675528
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675449
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675498
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675105
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675496
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675152
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675034
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675471
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675250
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675459
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675529
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675474
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674690
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675322
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675433
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675527
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675171
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675435
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675429
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675497
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675529
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.675486
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674692
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674728
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674273
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673929
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674519
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674065
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674663
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674740
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674617
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674604
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.672516
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673332
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674145
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674596
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674714
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674670
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674676
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673961
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674632
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674477
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674604
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674740
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674675
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674252
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674368
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674703
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674372
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674200
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673839
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673204
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674109
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674518
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674686
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673869
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674524
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674626
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674737
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674348
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674618
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674635
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674692
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674741
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674705
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.662028
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.673898
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673429
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673716
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673186
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673837
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673927
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673778
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.672330
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.672514
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.665964
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.670731
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.672818
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673377
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673834
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673868
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673779
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673780
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673590
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673749
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673922
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673869
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673904
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673597
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673896
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673543
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673346
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673774
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673190
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673798
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673929
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673739
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673007
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673698
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673811
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673919
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673480
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673781
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673826
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673870
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673929
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673888
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.659049
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665825
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665677
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.641004
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.665524
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665894
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665951
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665842
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.664659
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.664509
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.664157
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665317
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665591
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665948
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665964
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665566
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.664593
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665660
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665716
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665900
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665958
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665888
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665216
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665950
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665770
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665631
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.648009
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.665521
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665853
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665961
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665822
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665446
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665319
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665290
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.663411
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665698
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665852
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665922
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665892
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665964
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665952
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.658980
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665200
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665034
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.641001
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.664865
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.662334
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665303
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665207
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.664168
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.663759
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.663596
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.664981
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665307
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665317
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.664954
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.663977
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665033
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665267
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665262
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665309
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665238
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.664632
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.664300
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665127
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.664999
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.647968
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.664862
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.663959
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665315
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665189
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.664866
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.654386
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.664696
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.662927
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665299
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665201
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665269
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665199
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.664657
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.665308
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.605191
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602561
#          Iterations 6

# %%
#Finding the number of predictors that maximized Accuracy and minimized AIC and BIC
print("Accuracy:",models_best.Accuracy.loc[models_best.Accuracy == models_best.Accuracy.max()].index[0])
print("AIC:",models_best.apply(lambda row: row[1].aic, axis=1).idxmin())
print("BIC:",models_best.apply(lambda row: row[1].bic, axis=1).idxmin())
# Out:
# Accuracy: 31
# AIC: 40
# BIC: 16

# %%
#Best model based on classification accuracy
cm = confusion_matrix_test(test,test.Potability,models_best.loc[31,'model'],cutoff=0.5)
recall = cm[1,1]/(cm[1,1]+cm[0,1])
fpr = cm[0,1]/(cm[0,1]+cm[0,0])
print('Recall: {:.1%}'.format(recall),'FPR: {:.1%}'.format(fpr))
# Out:
# Classification accuracy = 71.6%
# Recall: 73.8% FPR: 8.4%

# %%
#Best model based on AIC
cm = confusion_matrix_test(test,test.Potability,models_best.loc[40,'model'],cutoff=0.5)
recall = cm[1,1]/(cm[1,1]+cm[0,1])
fpr = cm[0,1]/(cm[0,1]+cm[0,0])
print('Recall: {:.1%}'.format(recall),'FPR: {:.1%}'.format(fpr))
# Out:
# Classification accuracy = 70.6%
# Recall: 71.2% FPR: 9.2%

# %%
#Best model based on BIC 
cm = confusion_matrix_test(test,test.Potability,models_best.loc[16,'model'],cutoff=0.5)
recall = cm[1,1]/(cm[1,1]+cm[0,1])
fpr = cm[0,1]/(cm[0,1]+cm[0,0])
print('Recall: {:.1%}'.format(recall),'FPR: {:.1%}'.format(fpr))
# Out:
# Classification accuracy = 69.2%
# Recall: 72.6% FPR: 6.8%

# %% [markdown]
# ### Backward Selection
# *By Henry Shavel*

# %%
#backward
import time
def backward(predictors):
    
    tic = time.time()
    
    results = []
    
    for combo in itertools.combinations(predictors, len(predictors)-1):
        results.append(processSubset(combo))
    
    # Wrap everything up in a nice dataframe
    models = pd.DataFrame(results)
    
    # Choose the model with the highest classification accuracy
    best_model = models.loc[models['Accuracy'].argmax()]
    
    toc = time.time()
    print("Processed ", models.shape[0], "models on", len(predictors)-1, "predictors in", (toc-tic), "seconds.")
    
    # Return the best model, along with some other useful information about the model
    return best_model
def backward_selection():
    #Creating a list of the best models
    models_best = pd.DataFrame(columns=["Accuracy", "model"], index = range(1,len(X.columns)))

    tic = time.time()
    #Creating a list of possible predictors
    predictors = X.columns
    #creating model with predictors
    models_best.loc[len(predictors)] = processSubset(predictors)
    #running backward function
    while(len(predictors) > 1):  
        models_best.loc[len(predictors)-1] = backward(predictors)
        predictors = models_best.loc[len(predictors)-1]["model"].params.index[1:]

    toc = time.time()
    print("Total elapsed time:", (toc-tic), "seconds.")
    #returning list of best models
    return models_best
#caling the function
models_best = backward_selection()
best_sub_plots()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.602561
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602562
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602561
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602614
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602594
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.603384
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.603158
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602566
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.603005
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602604
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602580
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602581
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602574
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602746
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602573
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602960
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602562
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602772
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602622
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602748
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.613153
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.605191
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602846
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602607
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602957
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.603228
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602944
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.603577
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.603731
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602668
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602581
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602676
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602685
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.628003
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.614594
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.607878
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.603405
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602763
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602596
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602561
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.603376
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.608516
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602565
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.605716
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602625
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.605464
#          Iterations 6
# Processed  45 models on 44 predictors in 3.221681833267212 seconds.
# Optimization terminated successfully.
#          Current function value: 0.602962
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602960
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.603003
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602985
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.603733
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.603561
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602965
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.603398
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.603019
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602976
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602978
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602993
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.603165
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602981
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602960
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.603197
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.603016
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.603118
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.

#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.661350
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.633149
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.671333
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.648144
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.661349
#          Iterations 5
# Processed  6 models on 5 predictors in 0.07723188400268555 seconds.
# Optimization terminated successfully.
#          Current function value: 0.647542
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.661538
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.671584
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.648213
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.661530
#          Iterations 5
# Processed  5 models on 4 predictors in 0.05543804168701172 seconds.
# Optimization terminated successfully.
#          Current function value: 0.674697
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.672342
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.648405
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.674889
#          Iterations 4
# Processed  4 models on 3 predictors in 0.03868913650512695 seconds.
# Optimization terminated successfully.
#          Current function value: 0.674881
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.673311
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.674985
#          Iterations 4
# Processed  3 models on 2 predictors in 0.0265500545501709 seconds.
# Optimization terminated successfully.
#          Current function value: 0.676568
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676380
#          Iterations 4
# Processed  2 models on 1 predictors in 0.014605998992919922 seconds.
# Total elapsed time: 51.07260799407959 seconds.

# %%
#Finding the number of predictors that maximized Accuracy and minimized AIC and BIC
print("Accuracy:",models_best.Accuracy.loc[models_best.Accuracy == models_best.Accuracy.max()].index[0])
print("AIC:",models_best.apply(lambda row: row[1].aic, axis=1).idxmin())
print("BIC:",models_best.apply(lambda row: row[1].bic, axis=1).idxmin())
# Out:
# Accuracy: 22
# AIC: 13
# BIC: 10

# %%
#Best model based on classification accuracy
cm = confusion_matrix_test(test,test.Potability,models_best.loc[22,'model'],cutoff=0.5)
recall = cm[1,1]/(cm[1,1]+cm[0,1])
fpr = cm[0,1]/(cm[0,1]+cm[0,0])
print('Recall: {:.1%}'.format(recall),'FPR: {:.1%}'.format(fpr))
plt.figure()
#Best model based on AIC
cm = confusion_matrix_test(test,test.Potability,models_best.loc[13,'model'],cutoff=0.5)
recall = cm[1,1]/(cm[1,1]+cm[0,1])
fpr = cm[0,1]/(cm[0,1]+cm[0,0])
print('Recall: {:.1%}'.format(recall),'FPR: {:.1%}'.format(fpr))
plt.figure()
#Best model based on classification accuracy
cm = confusion_matrix_test(test,test.Potability,models_best.loc[10,'model'],cutoff=0.5)
recall = cm[1,1]/(cm[1,1]+cm[0,1])
fpr = cm[0,1]/(cm[0,1]+cm[0,0])
print('Recall: {:.1%}'.format(recall),'FPR: {:.1%}'.format(fpr))
# Out:
# Classification accuracy = 72.6%
# Recall: 76.2% FPR: 7.6%
# Classification accuracy = 70.6%
# Recall: 71.2% FPR: 9.2%
# Classification accuracy = 68.9%
# Recall: 68.0% FPR: 9.6%

# %%
#choosing the model with the highest classification accuracy from backward selection
best_in_model = models_best.loc[22,'model']
#creating an arracy for accuracies
accuracy = np.array([])
#running a for loop that tests all possible cubic transformations on the best model determined from backward selection
for i in X_backup.columns:
    model = sm.logit("Potability~" + "+".join(best_in_model.params.index[1:]) + "+I(" + i + "**2)+I(" + i + "**3)", data = train).fit()
    accuracy = np.append(accuracy,accuracytest(test,test.Potability,model,cutoff=0.5))
print(round(max(accuracy)*100,1),'%')
# Out:
# Optimization terminated successfully.
#          Current function value: 0.602492
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.605929
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.609496
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.606043
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.595655
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.609315
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.608428
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.609450
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.609710
#          Iterations 6
# 72.6 %

# %% [markdown]
# ### Code fitting the final model

# %% [markdown]
# Put the code(s) that fit the final model(s) in separate cell(s), i.e., the code with the `.ols()` or `.logit()` functions.

# %%
final_model = sm.logit("Potability~" + "+".join(best_in_model.params.index[1:]), data = train).fit()
final_model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.609815
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             Potability   No. Observations:                 1609
# Model:                          Logit   Df Residuals:                     1586
# Method:                           MLE   Df Model:                           22
# Date:                Sun, 12 Mar 2023   Pseudo R-squ.:                 0.09884
# Time:                        14:46:56   Log-Likelihood:                -981.19
# converged:                       True   LL-Null:                       -1088.8
# Covariance Type:            nonrobust   LLR p-value:                 1.153e-33
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                      -23.9065      3.939     -6.069      0.000     -31.627     -16.186
# ph                               2.8165      0.500      5.630      0.000       1.836       3.797
# Solids                           0.0004   9.38e-05      4.766      0.000       0.000       0.001
# Chloramines                     -0.4270      0.281     -1.521      0.128      -0.977       0.123
# Sulfate                          0.0842      0.010      8.115      0.000       0.064       0.105
# Conductivity                    -0.0138      0.006     -2.143      0.032      -0.027      -0.001
# Organic_carbon                  -0.0950      0.098     -0.974      0.330      -0.286       0.096
# ph_Hardness                     -0.0022      0.001     -2.258      0.024      -0.004      -0.000
# ph_Chloramines                   0.1448      0.025      5.714      0.000       0.095       0.195
# ph_Sulfate                      -0.0096      0.001     -8.918      0.000      -0.012      -0.008
# ph_Conductivity                 -0.0004      0.001     -0.844      0.399      -0.001       0.001
# Hardness_Solids               -2.95e-07   1.93e-07     -1.529      0.126   -6.73e-07    8.32e-08
# Hardness_Chloramines            -0.0016      0.001     -1.579      0.114      -0.004       0.000
# Hardness_Sulfate              5.571e-05   2.88e-05      1.932      0.053   -8.09e-07       0.000
# Hardness_Conductivity         3.777e-05   1.92e-05      1.970      0.049    1.84e-07    7.54e-05
# Solids_Chloramines           -1.209e-05   4.48e-06     -2.700      0.007   -2.09e-05   -3.31e-06
# Solids_Sulfate               -9.902e-07   1.73e-07     -5.730      0.000   -1.33e-06   -6.51e-07
# Solids_Conductivity           4.434e-08   8.16e-08      0.543      0.587   -1.16e-07    2.04e-07
# Solids_Organic_carbon        -9.351e-07   1.92e-06     -0.486      0.627    -4.7e-06    2.83e-06
# Solids_Trihalomethanes        4.074e-07   3.98e-07      1.023      0.306   -3.73e-07    1.19e-06
# Sulfate_Trihalomethanes         -0.0001   5.22e-05     -2.158      0.031      -0.000   -1.03e-05
# Conductivity_Organic_carbon      0.0002      0.000      1.199      0.230      -0.000       0.001
# Conductivity_Trihalomethanes  6.752e-05   3.84e-05      1.759      0.079   -7.72e-06       0.000
# ================================================================================================
# """

# %%
cm = confusion_matrix_test(test,test.Potability,final_model,cutoff=0.5)
print(cm[0,1])
recall = cm[1,1]/(cm[1,1]+cm[0,1])
fpr = cm[0,1]/(cm[0,1]+cm[0,0])
print('Recall: {:.1%}'.format(recall),'FPR: {:.1%}'.format(fpr))
# Out:
# Classification accuracy = 72.6%
# 19.0
# Recall: 76.2% FPR: 7.6%

# %% [markdown]
# ## Conclusions and Recommendations to stakeholder(s)
#
# You may or may not have code to put in this section. Delete this section if it is irrelevant.
